# %% [markdown]
# # The Bayesian LASSO Regression
#
# ## Rahmat Ashari
#
# **Fall 2021 PGE 383 Subsurface Machine Learning at The University of Texas at Austin**
#
# **Hildebrand Department of Petroleum & Geosystems Engineering - Cockrell School of Engineering**
#
# ra37697 - rahx@utexas.edu
#
# _____________________
#
# **Workflow supervision and review by:**
#
# **Instructor: Prof. Michael Pyrcz, Ph.D., P.Eng., Associate Professor, The Univeristy of Texas at Austin**
#
# [Twitter](https://twitter.com/geostatsguy) | [GitHub](https://github.com/GeostatsGuy) | [Website](http://michaelpyrcz.com) | [GoogleScholar](https://scholar.google.com/citations?user=QVZ20eQAAAAJ&hl=en&oi=ao) | [Book](https://www.amazon.com/Geostatistical-Reservoir-Modeling-Michael-Pyrcz/dp/0199731446) | [YouTube](https://www.youtube.com/channel/UCLqEr-xV-ceHdXXXrTId5ig)  | [LinkedIn](https://www.linkedin.com/in/michael-pyrcz-61a648a1)
#
# **Course TA: Ademide Mabadeje, Graduate Student, The University of Texas at Austin**
#
# [LinkedIn](https://www.linkedin.com/in/ademidemabadeje/)

# %% [markdown]
# ## Executive Summary
#
# The LASSO regression can be interpreted from the perspective of Bayesian statistics, where the mode of the posterior distribution can be seen as a point estimate for the parameters. A simple single-predictor model fitting was exercised and compared with the frequentist LASSO regression at different $\lambda$ values. Adopting the Bayesian approach to LASSO regression delivers the capability of assessing the uncertainty in the model parameters, as well as regularization.

# %% [markdown]
# ## The Theory
#
# From a Bayesian point of view, a linear regression model can be expressed as
#
# $$
# Y = \mu1 + \sum X \beta_i + \epsilon
# $$
#
# With $\epsilon \sim N(0, \sigma^2)$, a prior $p(\beta) = \prod g(\beta)$, and a likelihood $p(y) \sim N(\mu + X\beta, \sigma^2I)$. If $g(\beta)$ is a Laplace density with mean 0 and a scale parameter defined as a function of $\lambda$, then the posterior mode for $\beta$ is the LASSO solution (James et al, 2017).
#
# The Laplace prior for the $\beta$ is expressed as
#
# $$
# p(\beta | \sigma^2) = \prod\frac{\lambda}{2\sqrt{\sigma^2}} \exp(-\lambda\beta_i/\sqrt{\sigma^2})
# $$
#
# The prior is conditioned by $\sigma^2$ to guarantee unimodality in the posterior distribution (Park and Castella, 2008).

# %% [markdown]
# ## Import Dependencies and Workflow Set-ups

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
import pymc3 as pm
import warnings
seed = 2021

# the lines below are purely for aesthetics
plt.rcParams["font.family"] = "Helvetica"
plt.rcParams["font.size"] = 12
plt.rcParams['figure.dpi']= 100

# Hide ONLY deprecation warning
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# **note**
#
# The package `pymc3` is not installed by default with Anaconda installation. For Windows, installation is trivial by using conda. For MacOS (particularly if you are using arm chip), refer to https://github.com/pymc-devs/pymc/wiki/Installation-Guide-(MacOS)

# %% [markdown]
# ## Univariate Bayesian Lasso Regression
#
# In this section, the goal is to fit a linear regression with LASSO regularization to predict production using only permeability. A synthetic dataset `unconv_MV_v4.csv` will be used. This dataset is available at Dr. Pyrcz's GitHub data repository.

# %% [markdown]
# ### Read Data and Standardization
#
# As an intial step, it is always a good practice to examine the imported data. Instead of fitting in the features' original scale, the linear model will be fit in a standardized scale. I found that this could elucidate the posterior distribution better when it comes to visualization. However, standardization in linear regression is not necessary.

# %%
data = pd.read_csv("unconv_MV_v4.csv")
scaler = StandardScaler()
dataSt = pd.DataFrame(scaler.fit_transform(data))
dataSt.columns = data.columns
data.head()
# Out:
#    Well    Por  Perm    AI  Brittle   TOC    VR         Prod
# 0     1  12.08  2.92  2.80    81.40  1.16  2.31  1695.360819
# 1     2  12.38  3.53  3.22    46.17  0.89  1.88  3007.096063
# 2     3  14.02  2.59  4.01    72.80  0.89  2.72  2531.938259
# 3     4  17.67  6.75  2.63    39.81  1.08  1.88  5288.514854
# 4     5  17.52  4.57  3.18    10.94  1.51  1.90  2859.469624

# %% [markdown]
# The next step is to examine the summary statistics of the standardized data. This step can reveal if there is any extreme outliers present in the dataset.

# %%
dataSt.describe().transpose()
# Out:
#          count          mean       std       min       25%       50%  \
# Well     200.0 -6.661338e-18  1.002509 -1.723412 -0.861706  0.000000
# Por      200.0  2.620126e-16  1.002509 -2.848142 -0.701361  0.026605
# Perm     200.0 -5.662137e-17  1.002509 -1.853701 -0.699753 -0.171282
# AI       200.0  3.985701e-16  1.002509 -2.986650 -0.745137 -0.024493
# Brittle  200.0  1.824929e-16  1.002509 -2.640962 -0.738391  0.095646
# TOC      200.0  3.552714e-16  1.002509 -2.457313 -0.776361  0.082330
# VR       200.0  9.126033e-16  1.002509 -3.446814 -0.647507 -0.014330
# Prod     200.0  7.549517e-17  1.002509 -1.952114 -0.760415 -0.167875
#
#               75%       max
# Well     0.861706  1.723412
# Por      0.813617  2.887855
# Perm     0.554098  3.208033
# AI       0.665203  2.937664
# Brittle  0.716652  2.566186
# TOC      0.748466  2.476256
# VR       0.593853  3.018254
# Prod     0.573278  3.050219

# %% [markdown]
# Only `Perm` and `Prod` columns are needed in this exercise, and both look proper. A quick visualization never hurt!

# %%
x = dataSt["Perm"]
y = dataSt["Prod"]

plt.figure(figsize = (8,5))
plt.scatter(x, y, color = "black", s = 2)
plt.xlabel("Permeability [md]")
plt.ylabel("Production [MMSCFD]")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Building the Bayesian LASSO Model
#
# In this chunk, the linear regression model with LASSO regularization will be constructed. The likelihood is distributed normal distribution while the prior for the slope is distributed by a laplace prior. The prior for the intercept is flat. A hyperprior for $\sigma^2$ is distributed exponential. The $\lambda$ will be predifined.
#
# $$
# p(y | - ) \sim N(\mu1 + X\beta, \sigma^2)
# $$
#
# $$
# p(\beta | -) \sim Laplace(0, b)
# $$
#
# $$
# p(\sigma^2) \sim Exp(1)
# $$
#
# $$
# p(\mu) \sim Flat
# $$
#
# Where $b = \frac{\sqrt{\sigma^2}}{\lambda}$
#
# For this exercise, $\lambda = 0.05$

# %%
lambd = 0.05

with pm.Model() as bayesLassoUni:
    # declare priors
    intercept = pm.Flat("intercept")
    sigmaSq = pm.Exponential("sigma2", lam = 1)
    beta = pm.Laplace("beta", mu = 0, b = sigmaSq**0.5/lambd)
    
    # construct model
    modelMean = intercept + (beta * x)
    
    # define likelihood
    likelihood = pm.Normal('likelihood', mu = modelMean, sd = sigmaSq**0.5, observed = y)
    
    # set up posterior sampling 
    step = pm.NUTS(target_accept = 0.95)
    
    # get trace and maximum a posteriori (MAP)
    posteriorMode = pm.find_MAP()
    trace = pm.sample(draws = 1000, tune = 1000, step = step, start = posteriorMode,
                      random_seed = seed, return_inferencedata = True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:00<00:00 logp = -295.6, ||grad|| = 207.99]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, sigma2, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 21 seconds.

# %% [markdown]
# The mode of the posterior (a.k.a the Bayesian LASSO point estimates for the parameters)

# %%
print(posteriorMode)
# Out:
# {'intercept': array(1.5816683e-16), 'sigma2_log__': array(-0.69751892), 'beta': array(0.70504559), 'sigma2': array(0.4978189)}

# %% [markdown]
# The summary statistics for the posterior and the diagnostic plots

# %%
with bayesLassoUni:
    print(pm.stats.summary(trace))
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# intercept -0.001  0.050  -0.094    0.093      0.001    0.001    3717.0
# beta       0.705  0.049   0.613    0.796      0.001    0.001    3637.0
# sigma2     0.514  0.053   0.417    0.612      0.001    0.001    3430.0
#
#            ess_tail  r_hat
# intercept    2773.0    1.0
# beta         2534.0    1.0
# sigma2       2801.0    1.0

# %% [markdown]
# Examine the traceplots to see how the chains look like

# %%
with bayesLassoUni:
    pm.plot_trace(trace, figsize = (16,12))

plt.tight_layout()
plt.show()

# %% [markdown]
# Chains look stationary as expected!

# %% [markdown]
# ### Building the Frequentist Lasso Fit
#
# This is simply just to see how frequentist LASSO regularizarion performs for the same predictor and target features for comparison purposes.

# %%
# reshape for compatibility
X = x.values.reshape(-1,1)

# Lasso model
modelLasso = Lasso(alpha = lambd)
modelLasso.fit(X,y)
yhatLasso = modelLasso.predict(X)

# %% [markdown]
# ### Comparing Bayesian with Frequenstist Lasso

# %%
plt.figure(figsize = (8,5))
plt.scatter(x, y, color = "black", label = "data", s = 2)
pm.plot_posterior_predictive_glm(trace, samples = 1000, eval = np.linspace(-4, 4, 100), linewidth = 1, color = 'orange', alpha =0.1, 
                                 label = 'Bayes Posterior',lm = lambda x, sample: sample['intercept'] + sample['beta'] * x)
pm.plot_posterior_predictive_glm(trace, samples = 1000, eval = np.linspace(-4, 4, 100), 
                                 linewidth = 1, color = 'blue',
                                 label = 'Bayes Posterior Mode',
                                 lm = lambda x, sample: posteriorMode['intercept'] + posteriorMode['beta'] * x)
plt.plot(x, yhatLasso, color = "red", label = "Frequentist Lasso")
plt.xlabel("Permeability [md]")
plt.ylabel("Production [MMSCFD]")
plotTitle = r"Bayesian LASSO Posterior with $\lambda$ = " + str(lambd)
plt.title(plotTitle)
plt.xlim([min(x), max(x)])
plt.legend(frameon = False)
plt.show()

# %% [markdown]
# Observe that the frequentist and Bayesian (point) estimates for the slope are quite close. For the case of Bayesian LASSO regression, we can also assess the whole distribution of the slopes, which can be quite useful for uncertainty analysis.

# %% [markdown]
# ### The Effects of $\lambda$

# %% [markdown]
# **Notice**
#
# This might take a while: run at your own risk. It took my local machine about 1-2 mins to run the chunk below.
#
# In the chunk below, we are building similar model but at different $\lambda$ values

# %%
lambdaList = [0.01, 0.1, 0.5, 1000]

traceList = []
modeList = []

for l in lambdaList:
    with pm.Model() as bayesLassoUni:
        # declare priors
        intercept = pm.Flat("intercept")
        sigmaSq = pm.Exponential("sigma2", lam = 1)
        beta = pm.Laplace("beta", mu = 0, b = sigmaSq**0.5/l)

        # construct model
        modelMean = intercept + (beta * x)

        # define likelihood
        likelihood = pm.Normal('likelihood', mu = modelMean, sd = sigmaSq**0.5, observed = y)

        # set up posterior sampling 
        step = pm.NUTS(target_accept = 0.95)

        # get trace and maximum a posteriori (MAP)
        trace = pm.sample(draws = 1000, tune = 1000, step = step, 
                          random_seed = seed, return_inferencedata = True)
        posteriorMode = pm.find_MAP()
        
    traceList.append(trace)
    modeList.append(posteriorMode)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, sigma2, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:00<00:00 logp = -297.21, ||grad|| = 207.99]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, sigma2, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:00<00:00 logp = -294.91, ||grad|| = 207.99]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, sigma2, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:08<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 20 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:00<00:00 logp = -293.3, ||grad|| = 207.99]
#     </div>
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, sigma2, intercept]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:11<00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 23 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='21' class='' max='21' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [21/21 00:00<00:00 logp = -285.7, ||grad|| = 998.57]
#     </div>

# %% [markdown]
# Next, the frequentist LASSO regression will be built for different $\lambda$ values, to serve as comparisons

# %%
# Lasso model
yhatLassoList = []
for l in lambdaList:
    modelLasso = Lasso(alpha = l)
    modelLasso.fit(X,y)
    yhatLasso = modelLasso.predict(X)
    yhatLassoList.append(yhatLasso)

# %% [markdown]
# Visualization to compare how the parameters change at different $\lambda$ values

# %%
plt.figure(figsize = (16,12))
for idx,l in enumerate(lambdaList):
    plt.subplot(2,2,idx + 1)
    plt.scatter(x, y, color = "black", label = "data", s = 2)
    pm.plot_posterior_predictive_glm(traceList[idx], samples = 1000, eval = np.linspace(-4, 4, 100), linewidth = 1, color = 'orange', alpha = 0.01, 
                                     label = 'Bayes Posterior',lm = lambda x, sample: sample['intercept'] + sample['beta'] * x)
    pm.plot_posterior_predictive_glm(traceList[idx], samples = 1000, eval = np.linspace(-4, 4, 100), 
                                     linewidth = 1, color = 'blue',
                                     label = 'Bayes Posterior Mode',
                                     lm = lambda x, sample: modeList[idx]['intercept'] + modeList[idx]['beta'] * x)
    plt.plot(x, yhatLassoList[idx], color = "red", label = "Frequentist Lasso")
    plt.xlabel("Permeability [md]")
    plt.ylabel("Production [MMSCFD]")
    plotTitle = r"Bayesian LASSO Posterior with $\lambda$ = " + str(l)
    plt.title(plotTitle)
    plt.xlim([min(x), max(x)])
    plt.legend(frameon = False)
plt.show()

# %% [markdown]
# Notice that the slope for the frequentist LASSO regression decreases with increasing $\lambda$ more significantly than the Bayesian LASSO (point) estimate. At very high $\lambda$ value, we observe the slopes for both frequentist and Bayesian LASSO regression are approximately 0. This is expected because the global mean for the target feature is 0 after standardization, and the penalty term at large $\lambda$ value should drive the slope to be equal to the global mean.
#
# It is quite difficult to see the reduction in the slope for the Bayesian LASSO estimates. The code below shows the posterior modes for teh $\lambda$ values above (Special attention to the 'beta' element)

# %%
modeList
# Out:
# [{'intercept': array(1.45884498e-16),
#   'sigma2_log__': array(-0.6977159),
#   'beta': array(0.7051867),
#   'sigma2': array(0.49772085)},
#  {'intercept': array(1.45462877e-16),
#   'sigma2_log__': array(-0.69727269),
#   'beta': array(0.70486915),
#   'sigma2': array(0.49794149)},
#  {'intercept': array(1.51666538e-16),
#   'sigma2_log__': array(-0.69530289),
#   'beta': array(0.7034561),
#   'sigma2': array(0.4989233)},
#  {'intercept': array(0.),
#   'sigma2_log__': array(-0.36651292),
#   'beta': array(0.),
#   'sigma2': array(0.69314718)}]

# %% [markdown]
# ## References
#
# Work in Progress ~
